# %% [markdown]
# # A01: Make a repo! Welcome to your GitHub Bootcamp.
# -----------
# **Dr. Dave Wanik - Operations and Information Management - University of Connecticut**

# %% [markdown]
# ## Instructions
# By the end of A01, you will be able to:
# - Create a GitHub account and set up a professional landing page (profile README)
#   * See Dr. Dave's for reference: https://github.com/drdave-teaching/
# - Create a new repository and write a clear project README
# - Use GitHub Desktop to clone a repo and work locally
# - Use branches (`dev`) to make changes safely
# - Open a Pull Request (PR), merge it, and delete the branch
# - Run a small Python script that generates a boxplot from the California Housing dataset
#
# ---
#
# ## Rubric/What you will submit
# You will submit your link to your **GitHub repository** named: `A01_5512` containing:
#
# * `README.md` (project overview + how to run) # 10 points
# * `src/boxplot.py` (or boxplot.ipynb if you prefer notebook-only) # 40 points
# * `figs/boxplot.png` (saved output figure) # 40 points
# * Make sure your GitHub username is `OPIM5512_netID` # 10 points
#
# ---
#
# ## Part 0 — Accounts + Setup (10–15 minutes)
#
# ### 0.1 Create your GitHub account
# 1. Go to GitHub and create an account. Name it `OPIM5512_netID`.
# 2. Use your UConn email for authentication purposes.
#
# ### 0.2 Install GitHub Desktop
# 1. Download and install GitHub Desktop.
# 2. Sign in to GitHub Desktop using your GitHub account.
#
# > If GitHub Desktop asks about Git configuration (name/email), use your real name and your UConn email. We want UConn email for authentication purposes.
#
# ---
#
# ## Part 1 — Your GitHub landing page (Profile README)
#
# ### 1.1 Create your “special” profile README
# 1. On GitHub, create a new repository named **exactly** your username (case-sensitive).
#    - Example: if your username is `jane-doe`, create a repo called `jane-doe`.
# 2. Check the box: **“Add a README file”**
# 3. This README becomes your **public profile landing page**.
#
# ### 1.2 Update your profile README
# Edit `README.md` to include:
# - A short intro (1–2 sentences)
# - Your program / course (e.g., “MSBAPM @ UConn”)
# - 2–4 bullet points: skills you’re learning this semester
# - A fun line (optional, but encouraged)
#
# ✅ **Deliverable for Part 1:** Your GitHub profile shows a custom README when someone visits your account.
#
# ---
#
# ## Part 2 — Create the A01 repository (online)
#
# ### 2.1 Create the repo
# 1. Create a new GitHub repository named: **A01**
# 2. Set it to **Public** (unless your instructor says otherwise)
# 3. Check: **Add a README**
# 4. Add a `.gitignore` (choose **Python** if offered)
#
# ### 2.2 Write the A01 README (first draft)
# In `README.md`, include:
# - Title + 1-sentence purpose
# - What data is used (California Housing dataset)
# - How to run the script (you’ll fill this in more later)
# - Expected output (a saved boxplot image)
#
# ✅ **Deliverable for Part 2:** A01 repo exists on GitHub with a starter `README.md`.
#
# ---
#
# ## Part 3 — Clone to your computer with GitHub Desktop
#
# ### 3.1 Clone the repo locally
# 1. Open GitHub Desktop
# 2. Click **File → Clone Repository**
# 3. Select `A01`
# 4. Choose a local folder you can find again (e.g., `Documents/GitHub/`)
#
# ✅ **Checkpoint:** You can see the repo files on your computer.
#
# ---
#
# ## Part 4 — Create a `dev` branch (branch workflow)
#
# ### 4.1 Create and switch to `dev`
# In GitHub Desktop:
# 1. Click the **Current Branch** dropdown
# 2. Choose **New Branch**
# 3. Name it: `dev`
# 4. Create the branch
#
# ✅ **Rule:** All changes for A01 happen on `dev`, not `main`.
#
# ---
#
# ## Part 5 — Add a tiny plotting script (CA Housing boxplot)
#
# ### 5.1 Add project folders
# Inside your repo, create:
# - `src/`
# - `figs/`
#
# ### 5.2 Add the script
# Create a file at the repo-level: `requirements.txt`
# - Add this code
#
# ```
# pandas==2.1.4
# matplotlib>=3.8
# scikit-learn>=1.4
# ```
#
# Create a file at: `src/boxplot.py`
#
# The script should:
# - Load the California Housing dataset
# - Make at least **one boxplot** (we’ll specify which column(s) when we code)
# - Save the figure to: `figs/boxplot.png`
#
# > You are allowed to run the script in Google Colab, but the final **saved image file** must be committed into your GitHub repo.
#
# ✅ **Deliverable for Part 5:** `src/boxplot.py` exists and produces `figs/boxplot.png`.
#
# ---
#
# ## Part 6 — Commit + Push your work (from `dev`)
#
# ### 6.1 Commit in GitHub Desktop
# 1. You should see changed files listed in GitHub Desktop
# 2. Write a commit message like:
#    `Add CA housing boxplot script and output figure`
# 3. Click **Commit to dev**
#
# ### 6.2 Push to GitHub
# Click **Push origin**
#
# ✅ **Checkpoint:** Your GitHub repo shows a `dev` branch with your changes.
#
# ---
#
# ## Part 7 — Pull Request + Merge + Delete branch (GitHub website)
#
# ### 7.1 Open a Pull Request
# 1. Go to your repo on GitHub
# 2. You should see a prompt to “Compare & pull request”
# 3. Base: `main` ← Compare: `dev`
# 4. Title your PR clearly (example):
#    `A01: Add boxplot script`
#
# ### 7.2 Merge the PR
# 1. Click **Merge pull request**
# 2. Confirm merge
#
# ### 7.3 Delete the branch
# After merging, click **Delete branch** (this deletes `dev` on GitHub)
#
# ✅ **Final Check:** `main` now contains your script + figure + updated README.
#
# ---
#
# ## Grading checklist (what we’ll look for)
# - [ ] GitHub profile README exists and has meaningful content
# - [ ] Repo named `A01` exists
# - [ ] `README.md` explains how to run + what output to expect
# - [ ] `src/boxplot.py` (or notebook equivalent) is present
# - [ ] `figs/boxplot.png` is present and looks correct
# - [ ] Evidence of branch workflow: PR merged, `dev` deleted
#
# ---
#
# ## Common mistakes to avoid
# - Editing directly on `main` (don’t)
# - Forgetting to push commits to GitHub
# - Generating a plot but not saving `figs/boxplot.png`
# - README that doesn’t tell someone how to run your code

# %% [markdown]
# # Starter codes

# %% [markdown]
# ## Fetch CA housing data
# The California Housing dataset is loaded directly from scikit-learn using `fetch_california_housing`, which downloads the data and returns it as a pandas DataFrame.

# %%
from sklearn.datasets import fetch_california_housing
import pandas as pd

# Load California Housing dataset
housing = fetch_california_housing(as_frame=True)

# Features + target as a single DataFrame
df = housing.frame

# Quick check
print(df.head())
print(df.shape)

# you can save the boxplot...

# %% [markdown]
# ## How to run the boxplot.py script on your computer

# %%
# install the requirements txt file
pip install -r requirements.txt

# %%
# change your working directory as needed to the A01 repo
cd path/to/A01

# %%
# run the code
python src/boxplot.py
